# %% [markdown]
# ## Import Pandas:

# %%
import pandas as pd

# %% [markdown]
# ## Capture the path to the "ufo_sightings - no headers.csv" file on your Google Drive:

# %%
ufos_path = 'YOUR PATH HERE'

# %% [markdown]
# ## Define a list containing the column headers for the dataset:

# %%
headers = ['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)', 'duration (hours/min)', 'comments', 'date posted', 'latitude', 'longitude']

# %% [markdown]
# ## Fetch the file into a DataFrame - adding column headers in the process - and display it:

# %%
ufo_sightings = pd.read_csv(ufos_path, names=headers)
ufo_sightings
# Out:
# <ipython-input-7-a4db9b6aa85a>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path, names=headers)
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# ...
