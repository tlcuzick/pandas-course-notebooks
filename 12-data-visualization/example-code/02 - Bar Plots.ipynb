# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
# %matplotlib inline

# %%
house_path = 'YOUR PATH HERE'

# %%
houses = pd.read_csv(house_path)
houses.head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 221900.0         3        1.0         1180
# 1  6414100192  20141209T000000 538000.0         3        2.2         2570
# 2  5631500400  20150225T000000 180000.0         2        1.0          770
# 3  2487200875  20141209T000000 604000.0         4        3.0         1960
# 4  1954400510  20150218T000000 510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
houses['bedrooms'].head(100).plot(kind='bar')
# Out:
# <Axes: >

# %%
num_bedrooms = houses['bedrooms'].value_counts()
num_bedrooms
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
num_bedrooms.plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
num_bedrooms.sort_index(inplace=True)
num_bedrooms.plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
price_by_grade = houses.groupby('grade')['price'].mean()
price_by_grade
# Out:
# grade
# 1     142000.0
# 3     205666.7
# 4     214381.0
# 5     248524.0
# 6     301919.6
# 7     402590.3
# 8     542852.8
# 9     773513.2
# 10   1071771.1
# 11   1496841.7
# 12   2191222.0
# 13   3709615.4
# Name: price, dtype: float64

# %%
price_by_grade.plot(kind='bar')
# Out:
# <Axes: xlabel='grade'>
