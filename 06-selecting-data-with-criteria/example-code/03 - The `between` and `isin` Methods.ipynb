# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
house_path = 'YOUR PATH HERE'

# %%
house_sales = pd.read_csv(house_path)
house_sales.head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 221900.0         3        1.0         1180
# 1  6414100192  20141209T000000 538000.0         3        2.2         2570
# 2  5631500400  20150225T000000 180000.0         2        1.0          770
# 3  2487200875  20141209T000000 604000.0         4        3.0         1960
# 4  1954400510  20150218T000000 510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
between_6_n_10 = house_sales['bedrooms'].between(6, 10)
between_6_n_10_df = house_sales[between_6_n_10]

# %%
between_6_n_10_df.sort_values('bedrooms', inplace=True)
between_6_n_10_df.head()
# Out:
# <ipython-input-5-101864e30f32>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   between_6_n_10_df.sort_values('bedrooms', inplace=True)
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 209    6300000550  20140717T000000 464000.0         6        3.0         2300
# 12374  6746701090  20140619T000000 680000.0         6        2.0         1670
# 12339  5132000140  20150120T000000 415000.0         6        1.0         1370
# 12338  5132000140  20140618T000000 175000.0         6        1.0         1370
# 12310  7529500030  20140909T000000 385000.0         6        4.0         2700
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 209        3404     2.0           0     0  ...      7        1600
# ...

# %%
between_6_n_10_df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 4096   1997200215  20140507T000000  599999.0         9        4.5
# 4235   2902200015  20150106T000000  700000.0         9        3.0
# 15161  5566100170  20141029T000000  650000.0        10        2.0
# 19254  8812401450  20141229T000000  660000.0        10        3.0
# 13314   627300145  20140814T000000 1148000.0        10        5.2
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4096          3830      6988     2.5           0     0  ...      7
# 4235          3680      4400     2.0           0     0  ...      7
# 15161         3610     11914     2.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  lat   long  \
# 4096         2450           1380      1938             0    98103 47.7 -122.3
# ...

# %%
ufos_path = 'YOUR PATH HERE'
ufo_sightings = pd.read_csv(ufos_path)
ufo_sightings.head()
# Out:
# <ipython-input-8-6c1e654c6879>:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %%
ufo_sightings['shape'].value_counts()
# Out:
# shape
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# round            2
# crescent         2
# pyramid          1
# flare            1
# hexagon          1
# dome             1
# changed          1
# Name: count, dtype: int64

# %%
shapes = ufo_sightings['shape'].isin(['cigar','cylinder','cone'])
filtered = ufo_sightings[shapes]

# %%
filtered['shape'].value_counts()
# Out:
# shape
# cigar       2057
# cylinder    1283
# cone         316
# Name: count, dtype: int64
