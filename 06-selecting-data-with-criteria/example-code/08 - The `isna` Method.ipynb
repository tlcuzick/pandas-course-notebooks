# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
ufos_path = 'YOUR PATH HERE'

# %%
ufo_sightings = pd.read_csv(ufos_path)
ufo_sightings.head()
# Out:
# <ipython-input-3-87ccc3a49ac9>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %%
ufo_sightings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
null_state = ufo_sightings['state'].isna()
null_state.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: state, dtype: bool

# %%
ufo_sightings[null_state].head(10)
# Out:
#              datetime                                city state country  \
# 2    10/10/1955 17:00                chester (uk/england)   NaN      gb
# 6    10/10/1965 21:00                  penarth (uk/wales)   NaN      gb
# 18   10/10/1973 23:00                         bermuda nas   NaN     NaN
# 20   10/10/1974 21:30                  cardiff (uk/wales)   NaN      gb
# 24   10/10/1976 22:00       stoke mandeville (uk/england)   NaN      gb
# 35   10/10/1982 07:00              gisborne (new zealand)   NaN     NaN
# 39   10/10/1985 20:25                  leeds (uk/england)   NaN      gb
# 55   10/10/1993 03:00                   zlatoust (russia)   NaN     NaN
# 65   10/10/1996 20:00  lake macquarie (nsw&#44 australia)   NaN     NaN
# 103  10/10/2001 04:33          sydney (nsw&#44 australia)   NaN      au
#
#          shape duration (seconds) duration (hours/min)  \
# 2       circle                 20           20 seconds
# 6       circle                180         about 3 mins
# ...

# %%
null_country = ufo_sightings['country'].isna()

either_null = ufo_sightings[null_state | null_country]
either_null.head(10)
# Out:
#             datetime                           city state country     shape  \
# 1   10/10/1949 21:00                   lackland afb    tx     NaN     light
# 2   10/10/1955 17:00           chester (uk/england)   NaN      gb    circle
# 6   10/10/1965 21:00             penarth (uk/wales)   NaN      gb    circle
# 18  10/10/1973 23:00                    bermuda nas   NaN     NaN     light
# 20  10/10/1974 21:30             cardiff (uk/wales)   NaN      gb      disk
# 24  10/10/1976 22:00  stoke mandeville (uk/england)   NaN      gb     cigar
# 29  10/10/1979 22:00           saddle lake (canada)    ab     NaN  triangle
# 35  10/10/1982 07:00         gisborne (new zealand)   NaN     NaN      disk
# 39  10/10/1985 20:25             leeds (uk/england)   NaN      gb  triangle
# 40  10/10/1986 20:00                 holmes/pawling    ny     NaN   chevron
#
#    duration (seconds) duration (hours/min)  \
# 1                7200              1-2 hrs
# ...

# %%
len(either_null)
# Out:
# 12211

# %%
any_null = ufo_sightings.isna().any(axis=1)
any_null.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
any_null_df = ufo_sightings[any_null]
any_null_df.head(20)
# Out:
#             datetime                                city state country  \
# 1   10/10/1949 21:00                        lackland afb    tx     NaN
# 2   10/10/1955 17:00                chester (uk/england)   NaN      gb
# 6   10/10/1965 21:00                  penarth (uk/wales)   NaN      gb
# 18  10/10/1973 23:00                         bermuda nas   NaN     NaN
# 20  10/10/1974 21:30                  cardiff (uk/wales)   NaN      gb
# 24  10/10/1976 22:00       stoke mandeville (uk/england)   NaN      gb
# 29  10/10/1979 22:00                saddle lake (canada)    ab     NaN
# 35  10/10/1982 07:00              gisborne (new zealand)   NaN     NaN
# 39  10/10/1985 20:25                  leeds (uk/england)   NaN      gb
# 40  10/10/1986 20:00                      holmes/pawling    ny     NaN
# 47  10/10/1989 21:00                            kranklin    ky     NaN
# 55  10/10/1993 03:00                   zlatoust (russia)   NaN     NaN
# ...

# %%
len(any_null_df)
# Out:
# 13816

# %%
ufo_sightings['duration_seconds_numeric'] = pd.to_numeric(ufo_sightings['duration (seconds)'],errors='coerce')

# %%
seconds_nan = ufo_sightings[ufo_sightings['duration_seconds_numeric'].isna()]
seconds_nan[['duration (seconds)', 'duration_seconds_numeric']]
# Out:
#       duration (seconds)  duration_seconds_numeric
# 27822                 2`                       NaN
# 35692                 8`                       NaN
# 58591               0.5`                       NaN
