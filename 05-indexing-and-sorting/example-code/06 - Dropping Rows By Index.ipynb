# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
house_path = 'YOUR PATH HERE'

# %%
house_sales = pd.read_csv(house_path)
house_sales.head(10)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3        1.0         1180
# 1  6414100192  20141209T000000  538000.0         3        2.2         2570
# 2  5631500400  20150225T000000  180000.0         2        1.0          770
# 3  2487200875  20141209T000000  604000.0         4        3.0         1960
# 4  1954400510  20150218T000000  510000.0         3        2.0         1680
# 5  7237550310  20140512T000000 1225000.0         4        4.5         5420
# 6  1321400060  20140627T000000  257500.0         3        2.2         1715
# 7  2008000270  20150115T000000  291850.0         3        1.5         1060
# 8  2414600126  20150415T000000  229500.0         3        1.0         1780
# 9  3793500160  20150312T000000  323000.0         3        2.5         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
house_sales.drop(labels=4, inplace=True)
house_sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3        1.0         1180
# 1  6414100192  20141209T000000  538000.0         3        2.2         2570
# 2  5631500400  20150225T000000  180000.0         2        1.0          770
# 3  2487200875  20141209T000000  604000.0         4        3.0         1960
# 5  7237550310  20140512T000000 1225000.0         4        4.5         5420
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 5    101930     1.0           0     0  ...     11        3890           1530
#
# ...

# %%
house_sales.drop(labels=[2, 6, 8], inplace=True)
house_sales.head(10)
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000  221900.0         3        1.0         1180
# 1   6414100192  20141209T000000  538000.0         3        2.2         2570
# 3   2487200875  20141209T000000  604000.0         4        3.0         1960
# 5   7237550310  20140512T000000 1225000.0         4        4.5         5420
# 7   2008000270  20150115T000000  291850.0         3        1.5         1060
# 9   3793500160  20150312T000000  323000.0         3        2.5         1890
# 10  1736800520  20150403T000000  662500.0         3        2.5         3560
# 11  9212900260  20140527T000000  468000.0         2        1.0         1160
# 12   114101516  20140528T000000  310000.0         3        1.0         1430
# 13  6054650070  20141007T000000  400000.0         3        1.8         1370
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
house_sales.sort_values('sqft_living', inplace=True, ascending=False)
house_sales.head(10)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 12777  1225069038  20140505T000000 2280000.0         7        8.0
# 7252   6762700020  20141013T000000 7700000.0         6        8.0
# 3914   9808700762  20140611T000000 7062500.0         5        4.5
# 9254   9208900037  20140919T000000 6885000.0         6        7.8
# 8092   1924059029  20140617T000000 4668000.0         5        6.8
# 4411   2470100110  20140804T000000 5570000.0         5        5.8
# 14556  2303900035  20140611T000000 2888000.0         5        6.2
# 18302  6072800246  20140702T000000 3300000.0         5        6.2
# 1164   1247600105  20141020T000000 5110800.0         5        5.2
# 1448   8907500070  20150413T000000 5350000.0         5        5.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 12777        13540    307752     3.0           0     4  ...     12
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
house_sales.drop(house_sales.index[0:10], inplace=True)
house_sales.head(10)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 13411  2426039123  20150130T000000 2415000.0         5        4.8
# 19858  2524069078  20150122T000000 2700000.0         4        4.0
# 16773  1630700380  20150130T000000 1920000.0         5        5.8
# 18477  1346300150  20141020T000000 3300000.0         8        4.0
# 14032  3459900230  20141125T000000 1680000.0         4        3.8
# 4024   9175600025  20141007T000000  800000.0         7        6.8
# 12370  6065300370  20150506T000000 4208000.0         5        6.0
# 11871  8835800350  20150112T000000 1950000.0         4        3.2
# 10373  3303850390  20141212T000000 2983000.0         5        5.5
# 1315   7558700030  20150413T000000 5300000.0         6        6.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 13411         7880     24250     2.0           0     2  ...     13
# 19858         7850     89651     2.0           0     0  ...     12
# ...
