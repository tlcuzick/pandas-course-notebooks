# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
ufos_path = 'YOUR PATH HERE'

# %%
ufo_sightings = pd.read_csv(ufos_path)
ufo_sightings.head()
# Out:
# <ipython-input-5-87ccc3a49ac9>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %% [markdown]
# ## Verify that there are non-numeric values at index labels 27822, 35692, and 58591 in the "duration (seconds)" column:

# %%
ufo_sightings.loc[[27822, 35692, 58591]]
# Out:
#               datetime               city state country   shape  \
# 27822   2/2/2000 19:33              bouse    az      us     NaN
# 35692  4/10/2005 22:52         santa cruz    ca      us     NaN
# 58591  7/21/2006 13:00  ibague (colombia)   NaN     NaN  circle
#
#       duration (seconds) duration (hours/min)  \
# 27822                 2`   each a few seconds
# 35692                 8`        eight seconds
# 58591               0.5`          1/2 segundo
#
#                                                 comments date posted  \
# 27822  Driving through Plomosa Pass towards Bouse Loo...   2/16/2000
# 35692  2 red lights moving together and apart with a ...   4/16/2005
# 58591  Viajaba a 27.000 pies en un avion comercial ve...  10/30/2006
#
#          latitude   longitude
# 27822  33.9325000 -114.005000
# 35692  36.9741667 -122.029722
# 58591    4.440663  -75.244141

# %% [markdown]
# ## Delete these records from the DataFrame:

# %%
ufo_sightings.drop(labels=[27822, 35692, 58591], inplace=True)

# %%
ufo_sightings.loc[[27822, 35692, 58591]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-02af86304ed7> in <cell line: 1>()
# ----> 1 ufo_sightings.loc[[27822, 35692, 58591]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1330                     raise ValueError("Cannot index with multidimensional key")
#    1331
# -> 1332                 return self._getitem_iterable(key, axis=axis)
#    1333
#    1334             # nested tuple slicing
#
# ...

# %% [markdown]
# ## Convert the "duration (seconds)" column to a numeric data type:

# %%
ufo_sightings['duration (seconds)'] = pd.to_numeric(ufo_sightings['duration (seconds)'])

# %% [markdown]
# ## Delete the rows associated with the 100 longest sightings by duration:

# %%
ufo_sightings.sort_values('duration (seconds)', inplace=True, ascending=False)
ufo_sightings.head()
# Out:
#               datetime                     city state country   shape  \
# 559    10/1/1983 17:00  birmingham (uk/england)   NaN      gb  sphere
# 53384   6/3/2010 23:30          ottawa (canada)    on      ca   other
# 74660  9/15/1991 18:00               greenbrier    ar      us   light
# 64390  8/10/2012 21:00                   finley    wa      us   light
# 38261   4/2/1983 24:00                dont know   NaN     NaN     NaN
#
#        duration (seconds) duration (hours/min)  \
# 559            97836000.0             31 years
# 53384          82800000.0             23000hrs
# 74660          66276000.0             21 years
# 64390          52623200.0             2 months
# 38261          52623200.0             2 months
#
#                                                 comments date posted  \
# 559    Firstly&#44 I was stunned and stared at the ob...   4/12/2013
# 53384  ((HOAX??))  I was out in a field near mil&#44 ...    7/6/2010
# ...

# %%
ufo_sightings.drop(ufo_sightings.index[0:100], inplace=True)
ufo_sightings.head()
# Out:
#                datetime            city state country      shape  \
# 14813   1/15/2003 03:00     simi valley    ca      us     circle
# 14975   1/15/2008 12:00  san bernardino    ca      us     circle
# 36504   4/13/2009 22:00        franklin    nj      us      light
# 1224   10/13/1969 21:15      millington    tn      us  formation
# 66371   8/15/1991 03:00      chowchilla    ca      us       disk
#
#        duration (seconds) duration (hours/min)  \
# 14813            259200.0               3 days
# 14975            259200.0              30 days
# 36504            259200.0              3 days+
# 1224             259200.0             72 hours
# 66371            259200.0               3 days
#
#                                                 comments date posted  \
# 14813  Small red globes going to and from a satellite...  10/20/2005
# 14975  Circular impression in back yard about 80 to 1...   2/14/2008
# 36504  bright then dim flashing red white green light...   5/12/2009
# ...
