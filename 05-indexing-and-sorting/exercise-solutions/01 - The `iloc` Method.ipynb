# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %% [markdown]
# ## Programatically calculate the number of values in the "datetime" column of the UFO sightings dataset that can't be converted to actual datetimes:

# %%
ufos_path = 'YOUR PATH HERE'
ufo_sightings = pd.read_csv(ufos_path)
# Out:
# <ipython-input-3-60ea0c9e0214>:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)

# %% [markdown]
# ## Use `iloc` to fetch row the 27,823rd row of the UFO sightings dataset into a Series and preview it:

# %%
ufo_sightings.iloc[27822]
# Out:
# datetime                                                   2/2/2000 19:33
# city                                                                bouse
# state                                                                  az
# country                                                                us
# shape                                                                 NaN
# duration (seconds)                                                     2`
# duration (hours/min)                                   each a few seconds
# comments                Driving through Plomosa Pass towards Bouse Loo...
# date posted                                                     2/16/2000
# latitude                                                       33.9325000
# longitude                                                        -114.005
# Name: 27822, dtype: object

# %% [markdown]
# ## Which value in the row looks like it might cause a conversion error if its parent column is converted to a numeric data type?

# %% [markdown]
# **The "2`" in the "duration (seconds)" column (note the backtick after the 2)**

# %% [markdown]
# ## Use `iloc` to fetch row the 43,783rd row of the UFO sightings dataset into a Series and preview it.

# %%
ufo_sightings.iloc[43782]
# Out:
# datetime                                                  5/22/1974 05:30
# city                                         mescalero indian reservation
# state                                                                  nm
# country                                                               NaN
# shape                                                           rectangle
# duration (seconds)                                                    180
# duration (hours/min)                                            two hours
# comments                Huge rectangular object emmitting intense whit...
# date posted                                                     4/18/2012
# latitude                                                       33q.200088
# longitude                                                     -105.624152
# Name: 43782, dtype: object

# %% [markdown]
# ## Which value in the row looks like it might cause a conversion error if its parent column is converted to a numeric data type?

# %% [markdown]
# **The "33q.200088" in the "latitude" column (note the "q" mixed in with the numeric digits)**

# %% [markdown]
# ## Use `iloc` to select rows the 27,823rd AND 43,783rd rows - and ONLY the "duration (seconds)" and "latitude" columns - into a DataFrame:

# %%
ufo_sightings.iloc[[27822, 43782], [5, 9]]
# Out:
#       duration (seconds)    latitude
# 27822                 2`  33.9325000
# 43782                180  33q.200088

# %% [markdown]
# ## Use `iloc` to fetch rows 50000 through 59999 into a DataFrame. Assign the DataFrame to a variable.

# %%
slice = ufo_sightings.iloc[49999:59999]

# %% [markdown]
# ## Apply the `describe` method to the resulting DataFrame, including all data types:

# %%
slice.describe(include='all')
# Out:
#                datetime     city state country  shape duration (seconds)  \
# count             10000    10000  9264    8751   9808              10000
# unique             8633     5071    65       5     23                202
# top     7/15/2001 00:30  seattle    ca      us  light                300
# freq                 11       64  1131    7912   2130               1065
# mean                NaN      NaN   NaN     NaN    NaN                NaN
# std                 NaN      NaN   NaN     NaN    NaN                NaN
# min                 NaN      NaN   NaN     NaN    NaN                NaN
# 25%                 NaN      NaN   NaN     NaN    NaN                NaN
# 50%                 NaN      NaN   NaN     NaN    NaN                NaN
# 75%                 NaN      NaN   NaN     NaN    NaN                NaN
# max                 NaN      NaN   NaN     NaN    NaN                NaN
#
#        duration (hours/min)  \
# count                 10000
# unique                 1989
# ...

# %% [markdown]
# ## How many missing/NaN values are in the "state" and "shape" columns, respectively, for this slice of the DataFrame?

# %% [markdown]
# **736 and 192, respectively**
