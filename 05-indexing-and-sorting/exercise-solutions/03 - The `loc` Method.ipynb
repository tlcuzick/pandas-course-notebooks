# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
ufos_path = 'YOUR PATH HERE'

# %%
ufo_sightings = pd.read_csv(ufos_path)
ufo_sightings.head()
# Out:
# <ipython-input-16-87ccc3a49ac9>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %% [markdown]
# ## Fetch the row of the DataFrame associated with index label **7** (ALL columns) into a Series:

# %%
ufo_sightings.loc[7]
# Out:
# datetime                                                 10/10/1965 23:45
# city                                                              norwalk
# state                                                                  ct
# country                                                                us
# shape                                                                disk
# duration (seconds)                                                   1200
# duration (hours/min)                                           20 minutes
# comments                A bright orange color changing to reddish colo...
# date posted                                                     10/2/1999
# latitude                                                       41.1175000
# longitude                                                      -73.408333
# Name: 7, dtype: object

# %% [markdown]
# ## Fetch the rows of the DataFrame associated with index labels **7**, **11**, and **21** (ALL columns) into a DataFrame:

# %%
ufo_sightings.loc[[7, 11, 21]]
# Out:
#             datetime     city state country     shape duration (seconds)  \
# 7   10/10/1965 23:45  norwalk    ct      us      disk               1200
# 11  10/10/1968 19:00  brevard    nc      us  fireball                180
# 21  10/10/1974 23:00   hudson    ks      us     light               1200
#
#    duration (hours/min)                                           comments  \
# 7            20 minutes  A bright orange color changing to reddish colo...
# 11            3 minutes  silent red /orange mass of energy floated by t...
# 21            one hour?                               The light chased us.
#
#    date posted    latitude  longitude
# 7    10/2/1999  41.1175000 -73.408333
# 11   6/12/2008  35.2333333 -82.734444
# 21   7/25/2004  38.1055556 -98.659722

# %% [markdown]
# ## Fetch the rows of the DataFrame associated with index labels **7**, **11**, and **21** (columns "datetime", "city", "country", "shape", and "duration (seconds)" ONLY) into a DataFrame:

# %%
ufo_sightings.loc[[7, 11, 21], ["datetime", "city", "country", "shape", "duration (seconds)"]]
# Out:
#             datetime     city country     shape duration (seconds)
# 7   10/10/1965 23:45  norwalk      us      disk               1200
# 11  10/10/1968 19:00  brevard      us  fireball                180
# 21  10/10/1974 23:00   hudson      us     light               1200

# %% [markdown]
# ## Fetch the rows of the DataFrame associated with index labels **7 THROUGH 21** (columns "datetime", "city", "country", "shape", and "duration (seconds)" ONLY) into a DataFrame:

# %%
ufo_sightings.loc[7:21, ["datetime", "city", "country", "shape", "duration (seconds)"]]
# Out:
#             datetime                city country     shape duration (seconds)
# 7   10/10/1965 23:45             norwalk      us      disk               1200
# 8   10/10/1966 20:00           pell city      us      disk                180
# 9   10/10/1966 21:00            live oak      us      disk                120
# 10  10/10/1968 13:00           hawthorne      us    circle                300
# 11  10/10/1968 19:00             brevard      us  fireball                180
# 12  10/10/1970 16:00            bellmore      us      disk               1800
# 13  10/10/1970 19:00          manchester      us   unknown                180
# 14  10/10/1971 21:00           lexington      us      oval                 30
# 15  10/10/1972 19:00       harlan county      us    circle               1200
# 16  10/10/1972 22:30     west bloomfield      us      disk                120
# 17  10/10/1973 19:00             niantic      us      disk               1800
# ...
