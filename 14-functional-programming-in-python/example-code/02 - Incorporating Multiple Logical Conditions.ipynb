# %%
price = 444000
num_bathrooms = 3.75

# %%
if price >= 400000:
  print('Too expensive!')
elif (num_bathrooms - int(num_bathrooms)) == 0.25:
  print('Stupid number of bathrooms!')
elif (num_bathrooms - int(num_bathrooms)) == 0.75:
  print('Stupid number of bathrooms!')
else:
  print("I'm interested!")
# Out:
# Too expensive!
