# %%
val = print("I'm a function!")
# Out:
# I'm a function!

# %%
print(val)
# Out:
# None

# %%
val = len("I'm a function!")

# %%
print(val)
# Out:
# 15

# %%
def greet_me(name):
  string_to_print = 'Hi there ' + name + '!'
  print(string_to_print)

# %%
greet_me('Travis')
# Out:
# Hi there Travis!
