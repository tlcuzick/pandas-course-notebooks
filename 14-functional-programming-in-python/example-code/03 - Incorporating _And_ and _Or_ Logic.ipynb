# %%
price = 333000
num_bathrooms = 3
grade = 8
condition = 4

# %%
if price >= 400000:
  print('Too expensive!')
elif (num_bathrooms - int(num_bathrooms)) in(0.25, 0.75):
  print('Stupid number of bathrooms!')
elif (grade > 7) and (condition > 3):
  print("I'm interested!")
else:
  print("Not interested:(")
# Out:
# I'm interested!
