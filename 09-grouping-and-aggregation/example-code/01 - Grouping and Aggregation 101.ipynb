# %%
houses_path = 'YOUR PATH HERE'

# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
houses = pd.read_csv(houses_path)
houses.head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 221900.0         3        1.0         1180
# 1  6414100192  20141209T000000 538000.0         3        2.2         2570
# 2  5631500400  20150225T000000 180000.0         2        1.0          770
# 3  2487200875  20141209T000000 604000.0         4        3.0         1960
# 4  1954400510  20150218T000000 510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
gp = houses.groupby('bedrooms')
gp

# %%
gp.groups
# Out:
# {0: [875, 3119, 3467, 4868, 6994, 8477, 8484, 9773, 9854, 12653, 14423, 18379, 19452], 1: [154, 264, 350, 465, 648, 860, 903, 1066, 1149, 1378, 1389, 1457, 1629, 1653, 1734, 1956, 1971, 1975, 2008, 2026, 2031, 2156, 2687, 2927, 2930, 2973, 3042, 3108, 3223, 3253, 3285, 3303, 3383, 3489, 3582, 3602, 3661, 3805, 3837, 3874, 3984, 3987, 4089, 4146, 4390, 4410, 4446, 4651, 4832, 4890, 5135, 5168, 5369, 5570, 5582, 5752, 5832, 5887, 6086, 6105, 6120, 6562, 6779, 6812, 7017, 7261, 7375, 7619, 7636, 7725, 7776, 7949, 7992, 8080, 8133, 8165, 8213, 8262, 8445, 8532, 8533, 8600, 8619, 8623, 8732, 8800, 8814, 8955, 9037, 9131, 9191, 9272, 9406, 9457, 9518, 9545, 9563, 9820, 9821, 9888, ...], 2: [2, 11, 18, 23, 31, 53, 82, 88, 89, 107, 117, 122, 138, 140, 147, 166, 179, 183, 208, 215, 218, 219, 226, 230, 233, 241, 242, 244, 247, 255, 263, 267, 271, 281, 289, 308, 318, 324, 325, 333, 347, 353, 380, 395, 402, 411, 420, 424, 438, 442, 470, 478, 487, 495, 498, 501, 505, 508, 515, 521, 524, 525, 531,
# ...

# %%
gp.get_group(1)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 154    7920100045  20140516T000000 350000.0         1        1.0          700
# 264    2123039032  20141027T000000 369900.0         1        0.8          760
# 350    7325600160  20140604T000000 299000.0         1        0.8          560
# 465    8658300340  20140523T000000  80000.0         1        0.8          430
# 648     922049078  20141118T000000 157000.0         1        1.0          870
# ...           ...              ...      ...       ...        ...          ...
# 21326  6003000851  20140522T000000 353000.0         1        1.0          550
# 21332  9266700190  20150511T000000 245000.0         1        1.0          390
# 21443  3278600750  20150407T000000 250000.0         1        1.5         1180
# 21519  1702901618  20150407T000000 420000.0         1        2.0         1070
# 21552   688000017  20140627T000000 516500.0         1        1.2         1100
#
# ...

# %%
gp[['price','bathrooms']].mean()
# Out:
#              price  bathrooms
# bedrooms
# 0         409503.8        0.8
# 1         317642.9        1.1
# 2         401372.7        1.4
# 3         466232.1        2.0
# 4         635419.5        2.4
# 5         786599.8        2.8
# 6         825520.6        3.1
# 7         951184.7        3.7
# 8        1105076.9        3.6
# 9         893999.8        4.4
# 10        819333.3        3.4
# 11        520000.0        3.0
# 33        640000.0        1.8

# %%
houses.groupby('bedrooms')[['price','bathrooms']].mean()
# Out:
#              price  bathrooms
# bedrooms
# 0         409503.8        0.8
# 1         317642.9        1.1
# 2         401372.7        1.4
# 3         466232.1        2.0
# 4         635419.5        2.4
# 5         786599.8        2.8
# 6         825520.6        3.1
# 7         951184.7        3.7
# 8        1105076.9        3.6
# 9         893999.8        4.4
# 10        819333.3        3.4
# 11        520000.0        3.0
# 33        640000.0        1.8
