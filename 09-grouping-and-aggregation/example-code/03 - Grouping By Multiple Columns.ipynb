# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
houses_path = 'YOUR PATH HERE'

# %%
houses = pd.read_csv(houses_path)
houses.head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 221900.0         3        1.0         1180
# 1  6414100192  20141209T000000 538000.0         3        2.2         2570
# 2  5631500400  20150225T000000 180000.0         2        1.0          770
# 3  2487200875  20141209T000000 604000.0         4        3.0         1960
# 4  1954400510  20150218T000000 510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
multi_level = houses.groupby(['bedrooms','bathrooms']).agg(avg_price=('price','mean'),max_price=('price','max'),avg_sqft=('sqft_living','mean'))
multi_level
# Out:
#                     avg_price  max_price  avg_sqft
# bedrooms bathrooms
# 0        0.0         520371.4  1295650.0    2058.3
#          0.8         265000.0   265000.0     384.0
#          1.0         228000.0   228000.0     390.0
#          1.5         288000.0   288000.0    1430.0
#          2.5         299983.3   339950.0    1863.3
# ...                       ...        ...       ...
# 10       2.0         650000.0   650000.0    3610.0
#          3.0         660000.0   660000.0    2920.0
#          5.2        1148000.0  1148000.0    4590.0
# 11       3.0         520000.0   520000.0    3000.0
# 33       1.8         640000.0   640000.0    1620.0
#
# [144 rows x 3 columns]

# %%
multi_level.loc[(0,1)]
# Out:
# avg_price   228000.0
# max_price   228000.0
# avg_sqft       390.0
# Name: (0, 1.0), dtype: float64

# %%
multi_level.reset_index(inplace=True)
multi_level
# Out:
#      bedrooms  bathrooms  avg_price  max_price  avg_sqft
# 0           0        0.0   520371.4  1295650.0    2058.3
# 1           0        0.8   265000.0   265000.0     384.0
# 2           0        1.0   228000.0   228000.0     390.0
# 3           0        1.5   288000.0   288000.0    1430.0
# 4           0        2.5   299983.3   339950.0    1863.3
# ..        ...        ...        ...        ...       ...
# 139        10        2.0   650000.0   650000.0    3610.0
# 140        10        3.0   660000.0   660000.0    2920.0
# 141        10        5.2  1148000.0  1148000.0    4590.0
# 142        11        3.0   520000.0   520000.0    3000.0
# 143        33        1.8   640000.0   640000.0    1620.0
#
# [144 rows x 5 columns]

# %%
multi_level[(multi_level['bedrooms'] >= 7) & (multi_level['bathrooms'] >= 4)]
# Out:
#      bedrooms  bathrooms  avg_price  max_price  avg_sqft
# 118         7        4.0   689991.4   999000.0    3078.0
# 119         7        4.2  1637000.0  2450000.0    4170.0
# 120         7        4.5  1535000.0  3200000.0    4880.0
# 121         7        4.8  1592450.0  2300000.0    5340.0
# 122         7        5.5  1240000.0  1240000.0    6630.0
# 123         7        5.8   540000.0   540000.0    3700.0
# 124         7        6.8   800000.0   800000.0    7480.0
# 125         7        8.0  2280000.0  2280000.0   13540.0
# 132         8        4.0  2100000.0  3300000.0    5865.0
# 133         8        5.0   490000.0   490000.0    2800.0
# 134         8        6.0  2150000.0  2150000.0    4340.0
# 136         9        4.0  1400000.0  1400000.0    4620.0
# 137         9        4.5   939999.5  1280000.0    3740.0
# 138         9        7.5   450000.0   450000.0    4050.0
# 141        10        5.2  1148000.0  1148000.0    4590.0
