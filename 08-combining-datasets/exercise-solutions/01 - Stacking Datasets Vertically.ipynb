# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %% [markdown]
# ## Import the following files into DataFrames: "Order Details 2021.csv", "Order Details 2022.csv", and "Order Details 2023.csv".

# %%
order_details_2021 = pd.read_csv('YOUR PATH HERE')
order_details_2022 = pd.read_csv('YOUR PATH HERE')
order_details_2023 = pd.read_csv('YOUR PATH HERE')

# %% [markdown]
# ## Confirm that the data in the columns of the respective datasets align:

# %%
order_details_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57164 entries, 0 to 57163
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDetailID  57164 non-null  int64
#  1   OrderID        57164 non-null  int64
#  2   OrderQty       57164 non-null  int64
#  3   ProductID      57164 non-null  int64
#  4   UnitPrice      57164 non-null  float64
#  5   LineTotal      57164 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 2.6 MB

# %%
order_details_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124797 entries, 0 to 124796
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderDetailID  124797 non-null  int64
#  1   OrderID        124797 non-null  int64
#  2   OrderQuantity  124797 non-null  int64
#  3   ProductID      124797 non-null  int64
#  4   UnitPrice      124797 non-null  float64
#  5   LineTotal      124797 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 5.7 MB

# %%
order_details_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148155 entries, 0 to 148154
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderDetailID  148155 non-null  int64
#  1   OrderID        148155 non-null  int64
#  2   OrderQty       148155 non-null  int64
#  3   ProductID      148155 non-null  int64
#  4   UnitPrice      148155 non-null  float64
#  5   LineTotal      148155 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 6.8 MB

# %% [markdown]
# ## Rename the "OrderQuantity" column to "OrderQty":

# %%
order_details_2022.rename(columns={'OrderQuantity': 'OrderQty'}, inplace=True)
order_details_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124797 entries, 0 to 124796
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderDetailID  124797 non-null  int64
#  1   OrderID        124797 non-null  int64
#  2   OrderQty       124797 non-null  int64
#  3   ProductID      124797 non-null  int64
#  4   UnitPrice      124797 non-null  float64
#  5   LineTotal      124797 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 5.7 MB

# %%
order_details_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250100 entries, 0 to 250099
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderDetailID  250100 non-null  int64
#  1   OrderID        250100 non-null  int64
#  2   OrderQty       250100 non-null  int64
#  3   ProductID      250100 non-null  int64
#  4   UnitPrice      250100 non-null  float64
#  5   LineTotal      250100 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 11.4 MB

# %% [markdown]
# ## Create a new dataset consisting of the three Order Details datasets stacked together "vertically". The index of the combined dataset should consist of sequential integers.

# %%
all_order_details = pd.concat([order_details_2021, order_details_2022, order_details_2023], ignore_index=True)

# %%
all_order_details.head()
# Out:
#    OrderDetailID  OrderID  OrderQty  ProductID  UnitPrice  LineTotal
# 0              1        1         1         30      11.99      11.99
# 1              2        1         1         19       7.99       7.99
# 2              3        1         1         14      19.49      19.49
# 3              4        1         1         10      27.99      27.99
# 4              5        1         1         33       5.99       5.99

# %% [markdown]
# ## How many records are in the combined dataset?

# %%
len(all_order_details)
# Out:
# 330116

# %% [markdown]
# **330,116**
