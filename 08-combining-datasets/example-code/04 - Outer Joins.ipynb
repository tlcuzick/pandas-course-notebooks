# %%
import pandas as pd

# %%
customers_path = 'YOUR PATH HERE'
orders_2021_path = 'YOUR PATH HERE'

# %%
customers = pd.read_csv(customers_path)
orders_2021 = pd.read_csv(orders_2021_path)

# %%
customer_orders_2021 = pd.merge(customers, orders_2021, left_on='ID', right_on='CustomerID')
customer_orders_2021.head(10)
# Out:
#    ID              Name           Address           City State  OrderID  \
# 0   1  Allyson Espinoza  5194 Mendouno Dr   Philadelphia    PA      386
# 1   1  Allyson Espinoza  5194 Mendouno Dr   Philadelphia    PA      594
# 2   1  Allyson Espinoza  5194 Mendouno Dr   Philadelphia    PA      670
# 3   1  Allyson Espinoza  5194 Mendouno Dr   Philadelphia    PA      701
# 4   1  Allyson Espinoza  5194 Mendouno Dr   Philadelphia    PA      715
# 5   1  Allyson Espinoza  5194 Mendouno Dr   Philadelphia    PA     1289
# 6   1  Allyson Espinoza  5194 Mendouno Dr   Philadelphia    PA     1701
# 7   2      Rene Hartman   4781 Highway 95  St. Augustine    FL      414
# 8   2      Rene Hartman   4781 Highway 95  St. Augustine    FL      476
# 9   2      Rene Hartman   4781 Highway 95  St. Augustine    FL      624
#
#    CustomerID  OrderDate   OrderTimestamp  SubTotal
# 0           1  1/18/2021  1/18/2021 16:05     78.44
# 1           1  1/25/2021  1/25/2021 15:59    138.39
# ...

# %%
len(customer_orders_2021)
# Out:
# 17981

# %%
len(customers)
# Out:
# 1805

# %%
customer_orders_2021['ID'].nunique()
# Out:
# 242

# %%
all_customers = pd.merge(customers, orders_2021, left_on='ID', right_on='CustomerID', how='left')

# %%
len(all_customers)
# Out:
# 19544

# %%
1805 - 242
# Out:
# 1563

# %%
17981 + 1563
# Out:
# 19544

# %%
all_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19544 entries, 0 to 19543
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              19544 non-null  int64
#  1   Name            19544 non-null  object
#  2   Address         19544 non-null  object
#  3   City            19544 non-null  object
#  4   State           19544 non-null  object
#  5   OrderID         17981 non-null  float64
#  6   CustomerID      17981 non-null  float64
#  7   OrderDate       17981 non-null  object
#  8   OrderTimestamp  17981 non-null  object
#  9   SubTotal        17981 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 1.5+ MB

# %%
null_customerID = all_customers['CustomerID'].isna()
all_customers[null_customerID]
# Out:
#          ID              Name               Address          City State  \
# 17981   243     Cassius Henry  8447 East Lake Court  Jacksonville    FL
# 17982   244  Scarlet Fletcher      72540 Blanco Rd.      New York    NY
# 17983   245       Koen Durham        2751 Trail Way       Atlanta    GA
# 17984   246     Amaris Spence   7077 Blue Jay Drive       Chicago    IL
# 17985   247      Jaidyn Weeks      9099 Second Ave.       Atlanta    GA
# ...     ...               ...                   ...           ...   ...
# 19539  1801     David Serrano    6692 Bluefish Lane    Cincinnati    OH
# 19540  1802   Braedon Parsons  9037 Saddlehill Lane  Jacksonville    FL
# 19541  1803          Talia Yu       3764 Olive Hill    Louisville    KY
# 19542  1804    Pamela Barajas         2946 Frame Ct       Atlanta    GA
# 19543  1805   Campbell Dodson     5049 Teakwood Dr.  Jacksonville    FL
#
#        OrderID  CustomerID OrderDate OrderTimestamp  SubTotal
# ...

# %%
orders_2021.loc[1111, 'CustomerID'] = 111111

# %%
all_orders = pd.merge(customers, orders_2021, left_on='ID', right_on='CustomerID', how='right')
all_orders[all_orders['CustomerID'] == 111111]
# Out:
#       ID Name Address City State  OrderID  CustomerID  OrderDate  \
# 1111 NaN  NaN     NaN  NaN   NaN     1112      111111  2/14/2021
#
#        OrderTimestamp  SubTotal
# 1111  2/14/2021 20:25     27.99

# %%
all_orders['ID'].nunique()
# Out:
# 242

# %%
all_everything = pd.merge(customers, orders_2021, left_on='ID', right_on='CustomerID', how='outer')

# %%
all_everything [all_everything ['CustomerID'] == 111111]
# Out:
#        ID Name Address City State  OrderID  CustomerID  OrderDate  \
# 19543 NaN  NaN     NaN  NaN   NaN   1112.0    111111.0  2/14/2021
#
#         OrderTimestamp  SubTotal
# 19543  2/14/2021 20:25     27.99

# %%
all_everything['ID'].nunique()
# Out:
# 1805
