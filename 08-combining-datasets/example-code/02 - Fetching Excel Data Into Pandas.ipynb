# %%
import pandas as pd

# %%
orders_path = 'YOUR PATH HERE'

# %%
orders = pd.read_excel(orders_path, sheet_name='Orders - 2021')
orders.head()
# Out:
#    OrderID  CustomerID  OrderDate      OrderTimestamp  SubTotal
# 0        1         106 2021-01-01 2021-01-01 20:35:00     73.45
# 1        2         161 2021-01-01 2021-01-01 21:14:00      9.99
# 2        3         152 2021-01-01 2021-01-01 09:36:00    109.92
# 3        4         169 2021-01-01 2021-01-01 12:56:00     60.45
# 4        5         101 2021-01-01 2021-01-01 21:52:00     82.44

# %%
orders = pd.read_excel(orders_path, sheet_name=None)
orders
# Out:
# {'Orders - 2021':        OrderID  CustomerID  OrderDate      OrderTimestamp  SubTotal
#  0            1         106 2021-01-01 2021-01-01 20:35:00     73.45
#  1            2         161 2021-01-01 2021-01-01 21:14:00      9.99
#  2            3         152 2021-01-01 2021-01-01 09:36:00    109.92
#  3            4         169 2021-01-01 2021-01-01 12:56:00     60.45
#  4            5         101 2021-01-01 2021-01-01 21:52:00     82.44
#  ...        ...         ...        ...                 ...       ...
#  17976    17977          66 2021-12-31 2021-12-31 20:37:00     98.42
#  17977    17978          63 2021-12-31 2021-12-31 11:41:00     11.99
#  17978    17979          18 2021-12-31 2021-12-31 14:29:00     26.98
#  17979    17980         161 2021-12-31 2021-12-31 22:29:00     78.42
#  17980    17981          90 2021-12-31 2021-12-31 16:53:00     22.96
#
#  [17981 rows x 5 columns],
#  'Orders - 2022':        OrderID  CustomerID  OrderDate      OrderTimestamp  SubTotal
# ...

# %%
orders = pd.concat(pd.read_excel(orders_path, sheet_name=None), ignore_index=True)
orders.head()
# Out:
#    OrderID  CustomerID  OrderDate      OrderTimestamp  SubTotal
# 0        1         106 2021-01-01 2021-01-01 20:35:00     73.45
# 1        2         161 2021-01-01 2021-01-01 21:14:00      9.99
# 2        3         152 2021-01-01 2021-01-01 09:36:00    109.92
# 3        4         169 2021-01-01 2021-01-01 12:56:00     60.45
# 4        5         101 2021-01-01 2021-01-01 21:52:00     82.44

# %%
orders.tail()
# Out:
#         OrderID  CustomerID  OrderDate      OrderTimestamp  SubTotal
# 134967   134968         495 2023-11-01 2023-11-01 10:24:00     38.98
# 134968   134969         549 2023-11-01 2023-11-01 23:56:00     43.97
# 134969   134970         174 2023-11-01 2023-11-01 17:40:00    119.90
# 134970   134971        1269 2023-11-01 2023-11-01 23:38:00     51.45
# 134971   134972         378 2023-11-01 2023-11-01 21:50:00     28.46
