# %% [markdown]
# ## Create a variable called `favorite_number` and assign it...your favorite number. Then display the value stored in this variable.

# %%
favorite_number = 1111
favorite_number
# Out:
# 1111

# %% [markdown]
# ## Declare a variable "mood", and set it to a string describing your current mood. Then, on another line of the same cell, change the value of "mood" to a *different* mood. Running the cell should result in both the original and the new mood being displayed.

# %%
mood = 'contemplative'
print(mood)
mood = "crunk"
mood
# Out:
# contemplative
# 'crunk'

# %% [markdown]
# ## Create a variable called "chameleon" and initially set it to a string value (any string will do). Then change its value to an integer, and finally to a float. Print the variable after each assignment.

# %%
chameleon = "One, two, three, four."
print(chameleon)
chameleon = 1234
print(chameleon)
chameleon = 12.34
print(chameleon)
# Out:
# One, two, three, four.
# 1234
# 12.34

# %% [markdown]
# ## Create a variable `celsius` with a temperature value in Celsius. Then create a variable `fahrenheit` that converts this temperature to Fahrenheit using the formula: `(celsius * 9/5) + 32`. The cell should only display the fahrenheit temperature.

# %%
celsius = 32
fahrenheit = (celsius * 9/5) + 32
fahrenheit
# Out:
# 89.6

# %% [markdown]
# ## In a notebook cell, create variables `original_price` and `discount_percentage` for an item's original price and discount percentage, and populate them with values of your choosing. Then, in a subsequent cell, calculate the discounted price and store it in another variable, `final_price`. Display only the final price.

# %%
original_price = 142.77
discount_percentage = 25

# %%
final_price = original_price - (original_price * (discount_percentage / 100))
final_price
# Out:
# 107.07750000000001
