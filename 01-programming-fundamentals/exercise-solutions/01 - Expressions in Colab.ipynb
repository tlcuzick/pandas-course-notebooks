# %% [markdown]
# ## Create an expression that concatenates the string "Python is " with the string "awesome!", and display the result:

# %%
"Python is " + "awesome!"
# Out:
# 'Python is awesome!'

# %% [markdown]
# ## With a single Python expression, divide 17 by 3 using integer division, then square the result:

# %%
(17 // 3) ** 2
# Out:
# 25

# %% [markdown]
# ## On two distinct lines of a single Colab notebook cell, calculate the sum of 7 and 3, followed by the product of 5 and 4. The cell should output only display the result of the *second* expression (20).

# %%
7 + 3
5 * 4
# Out:
# 20

# %% [markdown]
# ## In a *single* cell of a Colab notebook, demonstrate the difference between multiplying the number 5 by 3 and multiplying the string "5" by 3. Running the cell should result in **two** distinct results being displayed: 15 and 555.

# %%
print(5 * 3)
'5' * 3
# Out:
# 15
# '555'

# %% [markdown]
# ## Write a single line of code that performs the following operations in order: 10 plus 5, multiplied by 2, raised to the power of 2, and then integer-divided by 17:

# %%
(((10 + 5) * 2) ** 2) // 17
# Out:
# 52
