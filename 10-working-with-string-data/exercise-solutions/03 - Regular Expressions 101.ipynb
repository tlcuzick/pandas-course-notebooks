# %% [markdown]
# ## Write a regular expression to match email addresses conforming to the following pattern:
#
# * (at least) any one character...
#
# * followed by an "@" character...
#
# * followed by (at least) any one character...
#
# * followed by ".com"

# %% [markdown]
# **`.+@.+\.com`**
