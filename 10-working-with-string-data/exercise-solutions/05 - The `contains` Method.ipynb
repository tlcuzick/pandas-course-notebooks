# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
ufos_path = 'YOUR PATH HERE'

# %%
sightings = pd.read_csv(ufos_path)
sightings.head()
# Out:
# <ipython-input-3-e5c2fbc31669>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %% [markdown]
# ## Create a filtered version of the UFO sightings dataset that only includes records where the sighting **comments** contain the word "hoax" (case insensitive):

# %%
sightings[sightings['comments'].str.contains('hoax', na=False, case=False)]
# Out:
#                datetime           city state country      shape  \
# 604     10/1/1994 13:13  new york city    ny      us       disk
# 739     10/1/2004 17:00      las vegas    nv      us   cylinder
# 878     10/1/2008 19:12         bonham    tx      us        egg
# 1107   10/12/2007 22:00         irvine    ca      us        NaN
# 1110   10/12/2007 23:00         rogers    ar      us    unknown
# ...                 ...            ...   ...     ...        ...
# 79773    9/7/2006 08:50   lewis center    oh      us       oval
# 79795    9/7/2008 23:00        oakland    me      us   fireball
# 80028    9/8/2010 11:30      lake city    mi      us  formation
# 80211    9/9/2006 22:00     farmington    mn      us   fireball
# 80237    9/9/2009 13:00       mesquite    nv      us        NaN
#
#       duration (seconds) duration (hours/min)  \
# 604                   15           15 seconds
# 739                    2        a few seconds
# 878                  300            5 minutes
# ...

# %% [markdown]
# ## Create a filtered version of the UFO sightings dataset that only includes records where the sighting **comments** contain a pattern matching a time:

# %%
time_regex = '\d{1}:\d{2}'
sightings[sightings['comments'].str.contains(time_regex, na=False, regex=True)]
# Out:
#                datetime            city state country     shape  \
# 60     10/10/1994 22:00      pinebergen    ar      us     light
# 85     10/10/1999 11:00       san diego    ca      us  fireball
# 108    10/10/2001 22:00         phoenix    az      us  triangle
# 142    10/10/2004 23:30         gleason    wi      us    sphere
# 152    10/10/2005 23:00  hendersonville    nc      us     light
# ...                 ...             ...   ...     ...       ...
# 80264    9/9/2010 11:30            troy    oh      us    sphere
# 80275    9/9/2011 09:30       hampstead    nc      us   diamond
# 80296    9/9/2012 16:36        waukegan    il      us    circle
# 80320    9/9/2013 20:20      tuscaloosa    al      us  fireball
# 80326    9/9/2013 21:00       woodstock    ga      us    sphere
#
#       duration (seconds) duration (hours/min)  \
# 60                     5            5 seconds
# 85                  3600               1 hour
# 108                   60   less then a minute
# ...
