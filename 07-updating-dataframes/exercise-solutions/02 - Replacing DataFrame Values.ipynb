# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
house_path = 'YOUR PATH HERE'

# %%
house_sales = pd.read_csv(house_path)
house_sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Replace the following list of values in the "bathrooms" column of the house sales dataset, with the nearest whole numbers:
#
# `[1.25,2.25,3.25,4.25,5.25,6.25]`

# %%
house_sales['bathrooms'].value_counts().sort_index()
# Out:
# bathrooms
# 0.00      10
# 0.50       4
# 0.75      72
# 1.00    3852
# 1.25       9
# 1.50    1446
# 1.75    3048
# 2.00    1930
# 2.25    2047
# 2.50    5380
# 2.75    1185
# 3.00     753
# 3.25     589
# 3.50     731
# 3.75     155
# 4.00     136
# 4.25      79
# 4.50     100
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 5.75       4
# 6.00       6
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# 8.00       2
# Name: count, dtype: int64

# %%
house_sales['bathrooms'] = house_sales['bathrooms'].replace([1.25,2.25,3.25,4.25,5.25,6.25], [1,2,3,4,5,6])

# %%
house_sales['bathrooms'].value_counts().sort_index()
# Out:
# bathrooms
# 0.00      10
# 0.50       4
# 0.75      72
# 1.00    3861
# 1.50    1446
# 1.75    3048
# 2.00    3977
# 2.50    5380
# 2.75    1185
# 3.00    1342
# 3.50     731
# 3.75     155
# 4.00     215
# 4.50     100
# 4.75      23
# 5.00      34
# 5.50      10
# 5.75       4
# 6.00       8
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# 8.00       2
# Name: count, dtype: int64
