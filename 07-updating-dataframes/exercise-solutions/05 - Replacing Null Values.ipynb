# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
ufos_path = 'YOUR PATH HERE'

# %%
sightings = pd.read_csv(ufos_path)
sightings.head()
# Out:
# <ipython-input-3-e5c2fbc31669>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %% [markdown]
# ## Replace all Null/empty values in the "state" and "country" columns of the UFO sightings dataset with the word "unknown":

# %%
sightings['state'].fillna('unknown',inplace=True)
sightings['country'].fillna('unknown',inplace=True)
sightings.head()
# Out:
#            datetime                  city    state  country     shape  \
# 0  10/10/1949 20:30            san marcos       tx       us  cylinder
# 1  10/10/1949 21:00          lackland afb       tx  unknown     light
# 2  10/10/1955 17:00  chester (uk/england)  unknown       gb    circle
# 3  10/10/1956 21:00                  edna       tx       us    circle
# 4  10/10/1960 20:00               kaneohe       hi       us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %% [markdown]
# ## Create a new, refreshed copy of the DataFrame by re-importing the UFO sightings dataset into a new DataFrame:

# %%
sightings = pd.read_csv(ufos_path)
sightings.head()
# Out:
# <ipython-input-6-e5c2fbc31669>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %% [markdown]
# ## Replace any Null/empty values in the "state" column with the corresponding values in the "country" column, AND replace any Null/empty values in the "country" column with the corresponding values in the "state" column:

# %%
sightings['state'].fillna(sightings['country'],inplace=True)
sightings['country'].fillna(sightings['state'],inplace=True)
sightings.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx      tx     light
# 2  10/10/1955 17:00  chester (uk/england)    gb      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...
