# %%
import pandas as pd

# %%
customers_path = 'YOUR PATH HERE'

# %%
customers = pd.read_csv(customers_path)
customers.head()
# Out:
#    ID                Name              Address           City State
# 0   1    Allyson Espinoza     5194 Mendouno Dr   Philadelphia    PA
# 1   2        Rene Hartman      4781 Highway 95  St. Augustine    FL
# 2   3      Ezekiel Dawson   2507 Pacific Ave S      Lexington    KY
# 3   4        Xander Stein  3614 Golf Club Road    Los Angeles    CA
# 4   5  Michelle Blanchard      4332 Listing Ct        Seattle    WA

# %%
dupes = customers.duplicated()
dupes
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1832    False
# 1833    False
# 1834    False
# 1835    False
# 1836     True
# Length: 1837, dtype: bool

# %%
customers[dupes]
# Out:
#         ID              Name                   Address           City State
# 40      40  Carlie Mccormick        1538 Golden Meadow   Jacksonville    FL
# 71      70   Armando Goodwin              8291 Chelsea       New York    NY
# 253    251      Toby Collier            9088 Creed Ave          Miami    FL
# 343    340       Jonah Grant    3397 Rancho View Drive     Louisville    KY
# 467    463    Leon Zimmerman         3397 C Olivera Rd       New York    NY
# 509    504    Nathen Skinner           5781 Sharon Dr.        Seattle    WA
# 746    740       Livia Cowan         7805 Roslyn Drive        Seattle    WA
# 773    766    Litzy Mccarthy  2526 N Willow Glen Court       New York    NY
# 950    942   Cadence Salazar        7393 Jacaranda Dr.  St. Augustine    FL
# 1014  1005     Journey Owens       7669 Willow Lake Rd        Seattle    WA
# 1092  1082   Brayden Esparza      1485 La Vista Avenue       New York    NY
# ...

# %%
customers[customers['ID'] == 40]
# Out:
#     ID              Name             Address          City State
# 39  40  Carlie Mccormick  1538 Golden Meadow  Jacksonville    FL
# 40  40  Carlie Mccormick  1538 Golden Meadow  Jacksonville    FL

# %%
customers.drop_duplicates(inplace=True)

# %%
customers[customers['ID'] == 40]
# Out:
#     ID              Name             Address          City State
# 39  40  Carlie Mccormick  1538 Golden Meadow  Jacksonville    FL

# %%
kinda_dupes = customers.duplicated(subset=['Name', 'Address', 'City','State'])
kinda_dupes
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1831    False
# 1832    False
# 1833    False
# 1834    False
# 1835    False
# Length: 1820, dtype: bool

# %%
customers[kinda_dupes]
# Out:
#         ID              Name                 Address           City State
# 77      76  Reynaldo English      7959 Driving Drive        Chicago    IL
# 142    141    Brenden Holmes  6713 Appalachian Drive        Seattle    WA
# 282    280    Isabelle Baker     1519 Mark Twain Dr.      Lexington    KY
# 464    461   Daphne Fletcher       7954 Vista Avenue       New York    NY
# 515    510    Karlee Bradley     8138 Golf Club Road       New York    NY
# 704    699    Selina Mullins     2769 San Jose Drive          Miami    FL
# 728    723      Justus Curry   9178 Sand Pointe Lane    Los Angeles    CA
# 735    730    Dulce Figueroa    9178 Thornhill Place    Los Angeles    CA
# 764    758   Cristian Duarte     7362 Arguello Blvd.          Miami    FL
# 1096  1086    Gordon Frazier        1870 Walnut Ave.      Lexington    KY
# 1105  1095      Katie Savage  8844, rue de Longchamp  St. Augustine    FL
# 1347  1336     Kianna Tucker     4666 Lancelot Drive   Philadelphia    PA
# ...

# %%
customers[customers['Name'].isin(['Reynaldo English', 'Justus Curry'])]
# Out:
#       ID              Name                Address         City State
# 76    75  Reynaldo English     7959 Driving Drive      Chicago    IL
# 77    76  Reynaldo English     7959 Driving Drive      Chicago    IL
# 727  722      Justus Curry  9178 Sand Pointe Lane  Los Angeles    CA
# 728  723      Justus Curry  9178 Sand Pointe Lane  Los Angeles    CA

# %%
customers.drop_duplicates(subset=['Name', 'Address', 'City','State'], inplace=True)

# %%
customers[customers['Name'].isin(['Reynaldo English', 'Justus Curry'])]
# Out:
#       ID              Name                Address         City State
# 76    75  Reynaldo English     7959 Driving Drive      Chicago    IL
# 727  722      Justus Curry  9178 Sand Pointe Lane  Los Angeles    CA

# %%
customers.loc[75:80]
# Out:
#     ID              Name               Address          City State
# 75  74      Aryanna Cook       3995 Tiffin Dr.       Atlanta    GA
# 76  75  Reynaldo English    7959 Driving Drive       Chicago    IL
# 78  77   Hayden Williams     6271 Ironwood Way       Seattle    WA
# 79  78   Adriel Arellano    5345 Willow Avenue    Cincinnati    OH
# 80  79     Jaiden Dalton  2236 Buena Vista Ave  Jacksonville    FL

# %%
customers = pd.read_csv(customers_path)

# %%
customers.drop_duplicates(subset=['Name', 'Address', 'City','State'], inplace=True, ignore_index=True)

# %%
customers.loc[75:80]
# Out:
#     ID             Name                  Address          City State
# 75  77  Hayden Williams        6271 Ironwood Way       Seattle    WA
# 76  78  Adriel Arellano       5345 Willow Avenue    Cincinnati    OH
# 77  79    Jaiden Dalton     2236 Buena Vista Ave  Jacksonville    FL
# 78  80    Karma Burnett        6022 La Salle Ct.       Seattle    WA
# 79  81   Keshawn Farmer  34703, rue des Bouchers    Cincinnati    OH
# 80  82       Micheal Le   7791 Mountain View Pl.       Seattle    WA

# %%
customers[customers['Name'].isin(['Reynaldo English', 'Justus Curry'])]
# Out:
#       ID              Name                Address         City State
# 74    75  Reynaldo English     7959 Driving Drive      Chicago    IL
# 715  722      Justus Curry  9178 Sand Pointe Lane  Los Angeles    CA
