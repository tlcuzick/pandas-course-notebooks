# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
ufos_path = 'YOUR PATH HERE'

# %%
ufo_sightings = pd.read_csv(ufos_path)
ufo_sightings.head()
# Out:
# <ipython-input-7-87ccc3a49ac9>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %%
ufo_sightings['country'].value_counts()
# Out:
# country
# us    65114
# ca     3000
# gb     1905
# au      538
# de      105
# Name: count, dtype: int64

# %%
updated_countries = ufo_sightings['country'].replace('de', 'germany')

# %%
updated_countries.value_counts()
# Out:
# country
# us         65114
# ca          3000
# gb          1905
# au           538
# germany      105
# Name: count, dtype: int64

# %%
old_country_names = ['us','ca','gb','au', 'de']
new_country_names = ['united states','canada','great britain','australia','germany']

updated_countries = ufo_sightings['country'].replace(old_country_names, new_country_names)

# %%
updated_countries.value_counts()
# Out:
# country
# united states    65114
# canada            3000
# great britain     1905
# australia          538
# germany            105
# Name: count, dtype: int64

# %%
ufo_sightings['country'] = updated_countries

# %%
ufo_sightings.head(10)
# Out:
#            datetime                  city state        country     shape  \
# 0  10/10/1949 20:30            san marcos    tx  united states  cylinder
# 1  10/10/1949 21:00          lackland afb    tx            NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN  great britain    circle
# 3  10/10/1956 21:00                  edna    tx  united states    circle
# 4  10/10/1960 20:00               kaneohe    hi  united states     light
# 5  10/10/1961 19:00               bristol    tn  united states    sphere
# 6  10/10/1965 21:00    penarth (uk/wales)   NaN  great britain    circle
# 7  10/10/1965 23:45               norwalk    ct  united states      disk
# 8  10/10/1966 20:00             pell city    al  united states      disk
# 9  10/10/1966 21:00              live oak    fl  united states      disk
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# ...
