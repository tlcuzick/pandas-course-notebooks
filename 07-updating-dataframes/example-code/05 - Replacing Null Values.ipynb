# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
ufos_path = 'YOUR PATH HERE'

# %%
ufo_sightings = pd.read_csv(ufos_path)
ufo_sightings.head()
# Out:
# <ipython-input-3-87ccc3a49ac9>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %%
ufo_sightings.fillna('?',inplace=True)
ufo_sightings.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx       ?     light
# 2  10/10/1955 17:00  chester (uk/england)     ?      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
ufo_sightings = pd.read_csv(ufos_path)
# Out:
# <ipython-input-5-195439c6c744>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_sightings = pd.read_csv(ufos_path)

# %%
ufo_sightings['shape'].value_counts(dropna=False)
# Out:
# shape
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# NaN           1932
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# round            2
# crescent         2
# pyramid          1
# flare            1
# hexagon          1
# dome             1
# changed          1
# Name: count, dtype: int64

# %%
ufo_sightings['shape'].fillna('unknown', inplace=True)
ufo_sightings['shape'].value_counts(dropna=False)
# Out:
# shape
# light        16565
# triangle      7865
# circle        7608
# unknown       7516
# fireball      6208
# other         5649
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# round            2
# crescent         2
# pyramid          1
# flare            1
# hexagon          1
# dome             1
# changed          1
# Name: count, dtype: int64

# %%
null_comments = ufo_sightings['comments'].isna()
ufo_sightings[null_comments]
# Out:
#                datetime                      city state country     shape  \
# 2940   10/19/2004 20:00              grand island    ne      us     light
# 14317   1/14/1996 17:00              chesterfield    va      us   unknown
# 21844   1/23/1996 20:15                     minot    nd      us   unknown
# 24999    1/7/1996 11:30                st. george    ut      us   unknown
# 28764   2/27/1996 22:01                   saginaw    mi      us   unknown
# 32337   3/19/2004 12:10                   atlanta    ga      us    circle
# 36089    4/1/2001 19:00         bangalore (india)   NaN     NaN   unknown
# 41782    5/1/2013 22:00                    toledo    oh      us      oval
# 46558   6/10/2002 03:30                 chantilly    va      us   unknown
# 48599   6/15/1957 02:30  atlantic ocean (bermuda)   NaN     NaN   unknown
# 49641   6/16/2013 12:00                 fairfield    ct      us      oval
# 52617   6/30/1956 18:30                   houston    tx      us  triangle
# ...

# %%
ufo_sightings['comments'].fillna(ufo_sightings['shape'], inplace=True)

# %%
ufo_sightings[null_comments]
# Out:
#                datetime                      city state country     shape  \
# 2940   10/19/2004 20:00              grand island    ne      us     light
# 14317   1/14/1996 17:00              chesterfield    va      us   unknown
# 21844   1/23/1996 20:15                     minot    nd      us   unknown
# 24999    1/7/1996 11:30                st. george    ut      us   unknown
# 28764   2/27/1996 22:01                   saginaw    mi      us   unknown
# 32337   3/19/2004 12:10                   atlanta    ga      us    circle
# 36089    4/1/2001 19:00         bangalore (india)   NaN     NaN   unknown
# 41782    5/1/2013 22:00                    toledo    oh      us      oval
# 46558   6/10/2002 03:30                 chantilly    va      us   unknown
# 48599   6/15/1957 02:30  atlantic ocean (bermuda)   NaN     NaN   unknown
# 49641   6/16/2013 12:00                 fairfield    ct      us      oval
# 52617   6/30/1956 18:30                   houston    tx      us  triangle
# ...
