# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
ufos_path = 'YOUR PATH HERE'

# %%
ufo_sightings = pd.read_csv(ufos_path)
ufo_sightings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB
# <ipython-input-3-4e7438d38d9e>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
no_nulls = ufo_sightings.dropna()
no_nulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66516 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              66516 non-null  object
#  1   city                  66516 non-null  object
#  2   state                 66516 non-null  object
#  3   country               66516 non-null  object
#  4   shape                 66516 non-null  object
#  5   duration (seconds)    66516 non-null  object
#  6   duration (hours/min)  66516 non-null  object
#  7   comments              66516 non-null  object
#  8   date posted           66516 non-null  object
#  9   latitude              66516 non-null  object
#  10  longitude             66516 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.1+ MB

# %%
only_all_nulls = ufo_sightings.dropna(how='all')
only_all_nulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
no_null_cols = ufo_sightings.dropna(axis=1)
no_null_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   duration (seconds)    80332 non-null  object
#  3   duration (hours/min)  80332 non-null  object
#  4   date posted           80332 non-null  object
#  5   latitude              80332 non-null  object
#  6   longitude             80332 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 4.3+ MB

# %%
no_null_shapes = ufo_sightings.dropna(subset='shape')
no_null_shapes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78400 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              78400 non-null  object
#  1   city                  78400 non-null  object
#  2   state                 72742 non-null  object
#  3   country               69001 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    78400 non-null  object
#  6   duration (hours/min)  78400 non-null  object
#  7   comments              78392 non-null  object
#  8   date posted           78400 non-null  object
#  9   latitude              78400 non-null  object
#  10  longitude             78400 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 7.2+ MB

# %%
ufo_sightings.dropna(subset='shape', inplace=True)
ufo_sightings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78400 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              78400 non-null  object
#  1   city                  78400 non-null  object
#  2   state                 72742 non-null  object
#  3   country               69001 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    78400 non-null  object
#  6   duration (hours/min)  78400 non-null  object
#  7   comments              78392 non-null  object
#  8   date posted           78400 non-null  object
#  9   latitude              78400 non-null  object
#  10  longitude             78400 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 7.2+ MB

# %%
ufo_sightings.loc[60:65]
# Out:
#             datetime                                     city state country  \
# 60  10/10/1994 22:00                               pinebergen    ar      us
# 61  10/10/1994 23:00  toronto (greater toronto area) (canada)    on      ca
# 64  10/10/1996 03:20                             higginsville    mo      us
# 65  10/10/1996 20:00       lake macquarie (nsw&#44 australia)   NaN     NaN
#
#        shape duration (seconds) duration (hours/min)  \
# 60     light                  5            5 seconds
# 61    sphere               3600              ~1 hour
# 64  triangle                  3                 3sec
# 65     light                300                5 min
#
#                                              comments date posted    latitude  \
# 60  Round&#44 bright&#44 low flying object silentl...   2/18/2001  34.1027778
# 61                                 Large rusty sphere    7/3/2013   43.666667
# 64  illuminated triangular craft&#44 flying at hig...   2/16/2000  39.0725000
# ...

# %%
ufo_sightings.reset_index(inplace=True)

# %%
ufo_sightings.loc[60:65]
# Out:
#     index          datetime                                     city state  \
# 60     60  10/10/1994 22:00                               pinebergen    ar
# 61     61  10/10/1994 23:00  toronto (greater toronto area) (canada)    on
# 62     64  10/10/1996 03:20                             higginsville    mo
# 63     65  10/10/1996 20:00       lake macquarie (nsw&#44 australia)   NaN
# 64     66  10/10/1996 22:00                               charleston    sc
# 65     67  10/10/1996 22:30                            monroe county    oh
#
#    country     shape duration (seconds) duration (hours/min)  \
# 60      us     light                  5            5 seconds
# 61      ca    sphere               3600              ~1 hour
# 62      us  triangle                  3                 3sec
# 63     NaN     light                300                5 min
# 64      us     light                300                5 min
# 65      us  cylinder                 60             1 minute
#
# ...
