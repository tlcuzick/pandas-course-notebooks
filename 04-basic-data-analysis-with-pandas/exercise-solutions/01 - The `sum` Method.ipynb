# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
house_path = 'YOUR PATH HERE'

# %%
house_sales = pd.read_csv(house_path)
house_sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Apply the `sum` method to the DataFrame:

# %%
house_sales.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                                38652488
# sqft_basement                                              6300385
# ...

# %% [markdown]
# ## Apply the `sum` method to the DataFrame once again, this time excluding any non-numeric columns from the output:

# %%
house_sales.sum(numeric_only=True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %% [markdown]
# ## Create a "new residents per bedroom" statistic, consisting of the 2014 level of net in-migration in Seattle (59,449), divided by the total number of bedrooms available in houses for sale in King County as of 2014:

# %%
bedrooms = house_sales['bedrooms'].sum()
in_migration_2014 = 59449

new_residents_per_bedroom = in_migration_2014 / bedrooms
new_residents_per_bedroom
# Out:
# 0.816001866747193
