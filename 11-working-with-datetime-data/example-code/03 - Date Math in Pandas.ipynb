# %%
import pandas as pd

# %%
ufos_path = 'YOUR PATH HERE'

# %%
sightings = pd.read_csv(ufos_path)
sightings['datetime'] = pd.to_datetime(sightings['datetime'],errors='coerce')
sightings['date posted'] = pd.to_datetime(sightings['date posted'],errors='coerce')
sightings.head()
# Out:
# <ipython-input-11-1d976520808f>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   sightings = pd.read_csv(ufos_path)
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %%
sightings['date posted'] - sightings['datetime']
# Out:
# 0       19922 days 03:30:00
# 1       20520 days 03:00:00
# 2       19095 days 07:00:00
# 3       17264 days 03:00:00
# 4       15808 days 04:00:00
#                 ...
# 80327      20 days 02:45:00
# 80328      20 days 02:00:00
# 80329      20 days 02:00:00
# 80330      20 days 01:40:00
# 80331      20 days 01:00:00
# Length: 80332, dtype: timedelta64[ns]

# %%
import datetime as dt

# %%
diff = sightings['date posted'] - sightings['datetime']
diff.dt.days
# Out:
# 0        19922.0
# 1        20520.0
# 2        19095.0
# 3        17264.0
# 4        15808.0
#           ...
# 80327       20.0
# 80328       20.0
# 80329       20.0
# 80330       20.0
# 80331       20.0
# Length: 80332, dtype: float64

# %%
diff = sightings['date posted'] - sightings['datetime']
sightings.insert(9, 'posting delay - months', diff.dt.days / 30.44)
sightings.head()
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted  \
# 0  This event took place in early fall around 194...  2004-04-27
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21
# ...

# %%
orders_path = '/content/drive/MyDrive/Data Analysis with Pandas/Datasets/PlantParcel/Orders.csv'
orders = pd.read_csv(orders_path)
orders.head()
# Out:
#    OrderID  CustomerID OrderDate  OrderTimestamp  SubTotal
# 0        1        1326  1/1/2021  1/1/2021 20:35     73.45
# 1        2        1047  1/1/2021  1/1/2021 21:14      9.99
# 2        3         839  1/1/2021   1/1/2021 9:36    109.92
# 3        4        1312  1/1/2021  1/1/2021 12:56     60.45
# 4        5        1535  1/1/2021  1/1/2021 21:52     82.44

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134972 entries, 0 to 134971
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   OrderID         134972 non-null  int64
#  1   CustomerID      134972 non-null  int64
#  2   OrderDate       134972 non-null  object
#  3   OrderTimestamp  134972 non-null  object
#  4   SubTotal        134972 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.1+ MB

# %%
orders['OrderDate'] = pd.to_datetime(orders['OrderDate'], errors='coerce')

# %%
orders['DeliverySLA'] = orders['OrderDate'] + pd.Timedelta(days=2)
orders.head(10)
# Out:
#    OrderID  CustomerID  OrderDate  OrderTimestamp  SubTotal DeliverySLA
# 0        1        1326 2021-01-01  1/1/2021 20:35     73.45  2021-01-03
# 1        2        1047 2021-01-01  1/1/2021 21:14      9.99  2021-01-03
# 2        3         839 2021-01-01   1/1/2021 9:36    109.92  2021-01-03
# 3        4        1312 2021-01-01  1/1/2021 12:56     60.45  2021-01-03
# 4        5        1535 2021-01-01  1/1/2021 21:52     82.44  2021-01-03
# 5        6         422 2021-01-01  1/1/2021 20:04    107.92  2021-01-03
# 6        7         219 2021-01-01  1/1/2021 17:25     10.99  2021-01-03
# 7        8         250 2021-01-02  1/2/2021 16:35     87.94  2021-01-04
# 8        9        1504 2021-01-02  1/2/2021 16:58     44.46  2021-01-04
# 9       10         183 2021-01-02  1/2/2021 14:25     23.97  2021-01-04
