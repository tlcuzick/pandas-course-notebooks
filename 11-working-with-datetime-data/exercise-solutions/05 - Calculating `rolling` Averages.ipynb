# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
houses_path = 'YOUR PATH HERE'

# %%
house_sales = pd.read_csv(houses_path)
house_sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Using the house sales dataset, create a breakout of number of homes sold AND average home sale price by year and month.

# %%
house_sales['date'] = pd.to_datetime(house_sales['date'], errors='coerce')

# %%
house_sales['month'] = house_sales['date'].dt.month
house_sales['year'] = house_sales['date'].dt.year

# %%
year_month_summary = house_sales.groupby(['year', 'month']).agg(homes_sold=('id','count'), avg_price=('price', 'mean'))
year_month_summary
# Out:
#             homes_sold      avg_price
# year month
# 2014 5            1768  548080.276584
#      6            2180  558002.199541
#      7            2211  544788.764360
#      8            1940  536445.276804
#      9            1774  529253.821871
#      10           1878  539026.971778
#      11           1411  521961.009213
#      12           1471  524461.866757
# 2015 1             978  525870.889571
#      2            1250  507851.371200
#      3            1875  543977.187200
#      4            2231  561837.774989
#      5             646  558126.811146

# %% [markdown]
# ## Add a second column to this view which displays the **weighted** average of home sale price for the previous three months, relative to a given year/month in the view.

# %%
num_sold_x_avg_price = year_month_summary['homes_sold'] * year_month_summary['avg_price']

# %%
rolling_num_sold_x_avg_price = num_sold_x_avg_price.rolling(window=3).sum()
rolling_num_sold = year_month_summary['homes_sold'].rolling(window=3).sum()

# %%
year_month_summary['weighted_3_month_avg_price'] = rolling_num_sold_x_avg_price / rolling_num_sold
year_month_summary
# Out:
#             homes_sold      avg_price  weighted_3_month_avg_price
# year month
# 2014 5            1768  548080.276584                         NaN
#      6            2180  558002.199541                         NaN
#      7            2211  544788.764360               550410.566975
#      8            1940  536445.276804               546781.960196
#      9            1774  529253.821871               537405.582278
#      10           1878  539026.971778               535030.895923
#      11           1411  521961.009213               530846.517282
#      12           1471  524461.866757               529467.025840
# 2015 1             978  525870.889571               523904.694301
#      2            1250  507851.371200               519221.235469
#      3            1875  543977.187200               528655.415550
#      4            2231  561837.774989               542985.719940
#      5             646  558126.811146               554286.031566
