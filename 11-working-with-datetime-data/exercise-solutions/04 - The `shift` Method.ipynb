# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
houses_path = 'YOUR PATH HERE'

# %%
house_sales = pd.read_csv(houses_path)
house_sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Create a summarized view that compares average home sale prices by year and month, to average sale prices in the previous year/month period:

# %%
house_sales['date'] = pd.to_datetime(house_sales['date'], errors='coerce')

# %%
house_sales['month'] = house_sales['date'].dt.month
house_sales['year'] = house_sales['date'].dt.year

# %%
avg_price_by_year_month = house_sales.groupby(['year', 'month'])['price'].mean()
avg_price_by_year_month = avg_price_by_year_month.to_frame()

# %%
avg_price_by_year_month['price - prev month'] = avg_price_by_year_month['price'].shift(1)
avg_price_by_year_month
# Out:
#                     price  price - prev month
# year month
# 2014 5      548080.276584                 NaN
#      6      558002.199541       548080.276584
#      7      544788.764360       558002.199541
#      8      536445.276804       544788.764360
#      9      529253.821871       536445.276804
#      10     539026.971778       529253.821871
#      11     521961.009213       539026.971778
#      12     524461.866757       521961.009213
# 2015 1      525870.889571       524461.866757
#      2      507851.371200       525870.889571
#      3      543977.187200       507851.371200
#      4      561837.774989       543977.187200
#      5      558126.811146       561837.774989

# %% [markdown]
# ## Enhance this view by adding a "% delta" column that displays the percentage increase/decrease from the previous month's average sale price to the current month's:

# %%
avg_price_by_year_month['% delta'] = ((avg_price_by_year_month['price'] - avg_price_by_year_month['price - prev month'])/ avg_price_by_year_month['price - prev month']) * 100
avg_price_by_year_month
# Out:
#                     price  price - prev month   % delta
# year month
# 2014 5      548080.276584                 NaN       NaN
#      6      558002.199541       548080.276584  1.810305
#      7      544788.764360       558002.199541 -2.367990
#      8      536445.276804       544788.764360 -1.531509
#      9      529253.821871       536445.276804 -1.340576
#      10     539026.971778       529253.821871  1.846590
#      11     521961.009213       539026.971778 -3.166068
#      12     524461.866757       521961.009213  0.479127
# 2015 1      525870.889571       524461.866757  0.268661
#      2      507851.371200       525870.889571 -3.426605
#      3      543977.187200       507851.371200  7.113462
#      4      561837.774989       543977.187200  3.283334
#      5      558126.811146       561837.774989 -0.660505
